# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#                        title  year
# 0        Captain of His Soul  1918
# 1             Qing chun xing  1975
# 2           Tangled Web (II)  2008
# 3  The Shepherd of the Hills  1919
# 4   Anna mit'n Flimmerfimmel  1919

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### What are the ten most common movie names of all time?

# %%
titles.title.value_counts().head(10)
# Out:
# Hamlet                  20
# Carmen                  17
# Macbeth                 16
# The Outsider            12
# The Three Musketeers    11
# Othello                 11
# Freedom                 11
# Temptation              11
# Maya                    11
# Kismet                  10
# Name: title, dtype: int64

# %% [markdown]
# ### Which three years of the 1930s saw the most films released?

# %%
t = titles[titles.year // 10 == 193]
t.year.value_counts().head(3)
# Out:
# 1937    1217
# 1938    1161
# 1936    1153
# Name: year, dtype: int64

# %% [markdown]
# ### Plot the number of films that have been released each decade over the history of cinema.

# %%
y = titles[titles.year // 10 <= 202]
(y.year // 10 * 10).value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Plot the number of "Hamlet" films made each decade.

# %%
a = titles[titles.title == 'Hamlet']
(a.year // 10 * 10).value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Plot the number of "Rustler" characters in each decade of the history of film.

# %%
b = cast[cast.character == 'Rustler']
(b.year // 10 * 10).value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Plot the number of "Hamlet" characters each decade.

# %%
h = cast[cast.character == 'Hamlet']
(h.year // 10 * 10).value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What are the 11 most common character names in movie history?

# %%
c = cast
c.character.value_counts().head(11)
# Out:
# Himself        19637
# Dancer         12019
# Extra          10848
# Reporter        7818
# Doctor          6963
# Party Guest     6786
# Student         6631
# Policeman       6424
# Bartender       6290
# Herself         6269
# Minor Role      6203
# Name: character, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Herself" in film history?

# %%
d = c[c.character == 'Herself']
d.name.value_counts().head(10)
# Out:
# Queen Elizabeth II        11
# María Luisa (V) Martín     9
# Luisa Horga                9
# Joyce Brothers             8
# Hillary Clinton            8
# Margaret Thatcher          8
# Joan Rivers                6
# Marta Berrocal             6
# Marilyn Monroe             6
# Inés J. Southern           6
# Name: name, dtype: int64

# %% [markdown]
# ### Who are the 10 people most often credited as "Himself" in film history?

# %%
e = c[c.character == 'Himself']
e.name.value_counts().head(10)
# Out:
# Adolf Hitler          91
# Richard Nixon         43
# Ronald Reagan         37
# John F. Kennedy       35
# George W. Bush        24
# Winston Churchill     24
# Martin Luther King    23
# Bill Clinton          22
# Benito Mussolini      21
# Ron Jeremy            20
# Name: name, dtype: int64

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1945?

# %%
f = c[c.year == 1945]
f.name.value_counts().head()
# Out:
# Emmett Vogan       37
# Sam (II) Harris    31
# Bess Flowers       28
# Harold Miller      28
# Franklyn Farnum    27
# Name: name, dtype: int64

# %% [markdown]
# ### Which actors or actresses appeared in the most movies in the year 1985?

# %%
g = c[c.year == 1985]
g.name.value_counts().head()
# Out:
# Mammootty        22
# Sukumari         20
# Shakti Kapoor    19
# Mohanlal         15
# Raj Babbar       15
# Name: name, dtype: int64

# %% [markdown]
# ### Plot how many roles Mammootty has played in each year of his career.

# %%
h = c[c.name == 'Mammootty']
h.year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What are the 10 most frequent roles that start with the phrase "Patron in"?

# %%
i = c[c.character.str.startswith('Patron in')]
i.character.value_counts().head(10)
# Out:
# Patron in Frisky Rabbit         16
# Patron in Chinese Restaurant     9
# Patron in the Coffee House       8
# Patron in Billiard Parlor        5
# Patron in Club                   3
# Patron in restaurant             3
# Patron in cabaret                3
# Patron in Restaurant             3
# Patron in Bar                    3
# Patron in booth                  2
# Name: character, dtype: int64

# %% [markdown]
# ### What are the 10 most frequent roles that start with the word "Science"?

# %%
j = c[c.character.str.startswith('Science')]
j.character.value_counts().head(10)
# Out:
# Science Teacher         57
# Science Fair Student     9
# Science Fair Judge       6
# Science Student          6
# Science Kid              5
# Science Fair Kid         5
# Science Reporter         5
# Science                  4
# Science Fair Teacher     3
# Science teacher          3
# Name: character, dtype: int64

# %% [markdown]
# ### Plot the n-values of the roles that Judi Dench has played over her career.

# %%
cast[(cast.name == 'Judi Dench') & (cast.n.notnull())].plot(x = 'year', y = 'n', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='n'>

# %% [markdown]
# ### Plot the n-values of Cary Grant's roles through his career.

# %%
cast[(cast.name == 'Cary Grant') & (cast.n.notnull())].plot(x = 'year', y = 'n', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='n'>

# %% [markdown]
# ### Plot the n-value of the roles that Sidney Poitier has acted over the years.

# %%
cast[(cast.name == 'Sidney Poitier') & (cast.n.notnull())].plot(x = 'year', y = 'n', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='n'>

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in the 1950s?

# %%
c[(c.year // 10 == 195) & (c.n == 1)].type.value_counts()
# Out:
# actor      6482
# actress    2985
# Name: type, dtype: int64

# %% [markdown]
# ### How many supporting (n=2) roles were available to actors, and how many to actresses, in the 1950s?

# %%
c[(c.year // 10 == 195) & (c.n == 2)].type.value_counts()
# Out:
# actor      4520
# actress    4496
# Name: type, dtype: int64

# %%
titles.head().title.str.startswith('A')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: title, dtype: bool

# %%
titles.year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
cast[cast.character == 'Ophelia'].plot(x = 'year', y = 'n', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='year', ylabel='n'>
